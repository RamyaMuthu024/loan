# %%
import pandas as pd

import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

import matplotlib.pyplot as plt
import seaborn as sns

# for interactivity
import ipywidgets as widgets
from ipywidgets import interact
from ipywidgets import interact_manual

from sklearn.metrics import classification_report, confusion_matrix
import sweetviz

import warnings
import pickle

import ppscore as pps

import missingno as mno
from sklearn import metrics

warnings.filterwarnings("ignore")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [6], in <cell line: 18>()
#      15 from ipywidgets import interact_manual
#      17 from sklearn.metrics import classification_report, confusion_matrix
# ---> 18 import sweetviz
#      20 import warnings
#      21 import pickle
#
# ModuleNotFoundError: No module named 'sweetviz'

# %%
train = pd.read_csv("train.csv")

# %%
print("Train data shape : ",train.shape)
# Out:
# Train data shape :  (744, 13)

# %%
train.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [3], in <cell line: 1>()
# ----> 1 train.head()
#
# NameError: name 'train' is not defined

# %%
train.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
train.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       744.000000         744.000000  716.000000        730.000000
# mean       5303.752688        1661.368172  147.458101        341.293151
# std        5721.971043        3321.309812   86.349928         66.559866
# min         150.000000           0.000000    9.000000         12.000000
# 25%        2894.000000           0.000000  100.000000        360.000000
# 50%        3800.000000        1128.500000  128.000000        360.000000
# 75%        5800.000000        2287.750000  172.000000        360.000000
# max       81000.000000       41667.000000  700.000000        480.000000
#
#        Credit_History
# count      687.000000
# mean         0.839884
# std          0.366981
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 744 entries, 0 to 743
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            744 non-null    object
#  1   Gender             728 non-null    object
#  2   Married            741 non-null    object
#  3   Dependents         726 non-null    object
#  4   Education          744 non-null    object
#  5   Self_Employed      705 non-null    object
#  6   ApplicantIncome    744 non-null    int64
#  7   CoapplicantIncome  744 non-null    float64
#  8   LoanAmount         716 non-null    float64
#  9   Loan_Amount_Term   730 non-null    float64
#  10  Credit_History     687 non-null    float64
#  11  Property_Area      744 non-null    object
#  12  Loan_Status        744 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 75.7+ KB

# %%
train["Loan_Status"].value_counts()
# Out:
# Y    509
# N    235
# Name: Loan_Status, dtype: int64

# %%
train["Loan_Status"] = train["Loan_Status"].replace("Y" , 1)
train["Loan_Status"] = train["Loan_Status"].replace("N" , 0)

# %%
plt.rcParams['figure.figsize'] = (15, 5)
plt.style.use('fivethirtyeight')

plt.subplot(1, 2, 1)
sns.countplot(train['Loan_Status'],)
plt.title("Distribution of Loan Status")


plt.subplot(1, 2, 2)
train['Loan_Status'].value_counts().plot(kind = 'pie', explode = [0, 0.05], autopct = '%.2f%%', startangle = 90,
                                       labels = ['Yes','No'], shadow = True, pctdistance = 0.5)
# Out:
# <Axes: ylabel='Loan_Status'>

# %% [markdown]
# # Missing Value

# %%
mno.bar(train,
        color= "orange",
        sort="ascending"
       )
plt.title("Missing value to second half of data")
plt.show()

# %%
train["Gender"].fillna(train["Gender"].mode()[0], inplace=True)
train["Married"].fillna(train["Married"].mode()[0], inplace=True)
train["Dependents"].fillna(train["Dependents"].mode()[0], inplace=True)
train["Self_Employed"].fillna(train["Self_Employed"].mode()[0], inplace=True)
train["Loan_Amount_Term"].fillna(train["Loan_Amount_Term"].mode()[0], inplace=True)
train["Credit_History"].fillna(train["Credit_History"].mode()[0], inplace=True)
train["LoanAmount"].fillna(train["LoanAmount"].median(), inplace=True)

# %%
mno.bar(train,
        color= "orange",
        sort="ascending"
       )
plt.title("Missing value to second half of data")
plt.show()

# %%
train.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# # Data Visualization

# %% [markdown]
# ## <center>Univariate Analysis</center>

# %%
plt.subplot(2,2,1)
train["Married"].value_counts().plot.bar(figsize=(20,10))
plt.title("Married")

plt.subplot(2,2,2)
train["Gender"].value_counts().plot.bar()
plt.title("Gender")

plt.subplot(2,2,3)
train["Self_Employed"].value_counts().plot.bar()
plt.title("Self_Employed")

plt.subplot(2,2,4)
train["Credit_History"].value_counts().plot.bar()
plt.title("Credit_History")

plt.show()

# %%
plt.subplot(1,3,1)
train["Dependents"].value_counts().plot.bar()
plt.title("Dependents")

plt.subplot(1,3,2)
train["Education"].value_counts().plot.bar()
plt.title("Education")

plt.subplot(1,3,3)
train["Property_Area"].value_counts().plot.bar()
plt.title("Property_Area")



plt.show()

# %%
plt.rcParams["figure.figsize"] =(15,7)
sns.distplot(train["ApplicantIncome"], color="black")
plt.title("Distribution of Applicant Income", fontsize=15)
plt.grid()
plt.show()

# %%
plt.rcParams["figure.figsize"] =(15,5)
sns.boxplot(y =train["ApplicantIncome"])
plt.title("Applicant Income")
plt.show()

# %%
sns.boxplot(train["CoapplicantIncome"])
plt.show()

# %% [markdown]
# ## <center>Bivariate Analysis</center>

# %%
plt.rcParams['figure.figsize'] = (15,4)
x = pd.crosstab(train['Education'], train['Loan_Status'])
colors = plt.cm.magma(np.linspace(0, 1, 3))
x.div(x.sum(1).astype(float), axis = 0).plot(kind = 'bar', stacked = False, color = colors)
plt.title('Effect of Education on Loan Status', fontsize = 15)
plt.xlabel(' ')
plt.show()

# %%
plt.rcParams['figure.figsize'] = (15, 3)
x = pd.crosstab(train['Gender'], train['Loan_Status'])
colors = plt.cm.cividis(np.linspace(0, 1, 5))
x.div(x.sum(1).astype(float), axis = 0).plot(kind = 'bar', stacked = False, color = colors)
plt.title('Effect of Gender on Loan Status', fontsize = 15)
plt.xlabel(' ')
plt.show()

# %%
plt.rcParams['figure.figsize'] = (15,4)
x = pd.crosstab(train['Dependents'], train['Loan_Status'])
colors = plt.cm.viridis(np.linspace(0, 1, 3))
x.div(x.sum(1).astype(float), axis = 0).plot(kind = 'area', stacked = False, color = colors)
plt.title('Effect of Department on Loan Status', fontsize = 15)
plt.xticks(rotation = 20)
plt.xlabel(' ')
plt.show()

# %%
plt.rcParams['figure.figsize'] = (15, 4)
def bivariate_plot(column1 = list(train.select_dtypes('object').columns),
                   column2 = list(train.select_dtypes('number').columns[1:])):
    sns.barplot(train[column1], train[column2])

# %% [markdown]
# ## <center>Multivariate Analysis</Center>

# %%
plt.rcParams['figure.figsize'] = (15, 8)
sns.heatmap(train.corr(), annot = True, linewidth = 0.5, cmap = 'Wistia')
plt.title('Correlation Heat Map', fontsize = 15)
plt.show()

# %% [markdown]
# # Outlier Treatment

# %%
plt.rcParams["figure.figsize"] = (12,5)
train["LoanAmount"].hist(bins=20),
plt.show()

# %%
train["LoanAmount_log"] = np.log(train["LoanAmount"])

# %%
train["LoanAmount_log"].hist(bins=20)
plt.show()

# %%
train["total_income"] = train["ApplicantIncome"] + train["CoapplicantIncome"]

# %%
np.log(train["total_income"]).hist(bins=20)
plt.show()

# %%
train["total_income"] = np.log(train.total_income)

# %% [markdown]
# # Model Building

# %%
train.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status',
#        'LoanAmount_log', 'total_income'],
#       dtype='object')

# %%
x_label = ['Loan_ID', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount']

y_label = ["Loan_Status"]

# %%
train = train.drop(x_label,1)

# %%
x = train.drop("Loan_Status",1)
y = train.Loan_Status

# %%
print(x.shape)
print(y.shape)
# Out:
# (744, 10)
# (744,)

# %%
x.head()
# Out:
#   Gender Married Dependents     Education Self_Employed  Loan_Amount_Term  \
# 0   Male      No          0      Graduate            No             360.0
# 1   Male     Yes          1      Graduate            No             360.0
# 2   Male     Yes          0      Graduate           Yes             360.0
# 3   Male     Yes          0  Not Graduate            No             360.0
# 4   Male      No          0      Graduate            No             360.0
#
#    Credit_History Property_Area  LoanAmount_log  total_income
# 0             1.0         Urban        4.852030      8.674026
# 1             1.0         Rural        4.852030      8.714568
# 2             1.0         Urban        4.189655      8.006368
# 3             1.0         Urban        4.787492      8.505323
# 4             1.0         Urban        4.948760      8.699515

# %%
x = pd.get_dummies(x)

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3,stratify =y, random_state=0, shuffle=True)

# %%
y_test.value_counts(normalize=True)
# Out:
# 1    0.683036
# 0    0.316964
# Name: Loan_Status, dtype: float64

# %%
y_train.value_counts(normalize=True)
# Out:
# 1    0.684615
# 0    0.315385
# Name: Loan_Status, dtype: float64

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (520, 19)
# (224, 19)
# (520,)
# (224,)

# %% [markdown]
# ###  Logistic Regression

# %%
lr = LogisticRegression()
lr.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
from sklearn.metrics import f1_score

# %%
lr.score(x_train, y_train)
# Out:
# 0.7942307692307692

# %%
lr.score(x_test, y_test)
# Out:
# 0.8303571428571429

# %%
print("Accuracy is", lr.score(x_test, y_test)*100)
# Out:
# Accuracy is 83.03571428571429

# %%
y_pred = lr.predict(x_test)

# %%
pd.DataFrame(classification_report(y_test, y_pred, output_dict=True))
# Out:
#                    0           1  accuracy   macro avg  weighted avg
# precision   0.923077    0.810811  0.830357    0.866944      0.846395
# recall      0.507042    0.980392  0.830357    0.743717      0.830357
# f1-score    0.654545    0.887574  0.830357    0.771060      0.813712
# support    71.000000  153.000000  0.830357  224.000000    224.000000

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[ 36,  35],
#        [  3, 150]], dtype=int64)

# %%
conf_matrix = confusion_matrix(y_true=y_test, y_pred=y_pred)
fig, ax = plt.subplots(figsize=(5, 5))
ax.matshow(conf_matrix, cmap=plt.cm.Oranges)
for i in range(conf_matrix.shape[0]):
    for j in range(conf_matrix.shape[1]):
        ax.text(x=j, y=i,s=conf_matrix[i, j], va='center', ha='center', size='x-small')
plt.xlabel('Predictions', fontsize=10)
plt.ylabel('Actuals', fontsize=10)
plt.title('Confusion Matrix of LOGISTIC REGRESSION', fontsize=10)
plt.show()

# %% [markdown]
# # DecisionTreeClassifier

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dtc =  DecisionTreeClassifier()

# %%
dtc.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
dtc.score(x_train, y_train)
# Out:
# 1.0

# %%
dtc.score(x_test, y_test)
# Out:
# 0.8392857142857143

# %%
dtc = DecisionTreeClassifier(min_samples_split=20, max_depth=3 )

# %%
dtc.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=3, min_samples_split=20)

# %%
dtc.score(x_train, y_train)
# Out:
# 0.8096153846153846

# %%
dtc.score(x_test, y_test)
# Out:
# 0.8392857142857143

# %%
print("Accuracy is", dtc.score(x_test, y_test)*100)
# Out:
# Accuracy is 83.92857142857143

# %%
y_pred = dtc.predict(x_test)
pd.DataFrame(classification_report(y_test, y_pred, output_dict=True))
# Out:
#                    0           1  accuracy   macro avg  weighted avg
# precision   0.948718    0.816216  0.839286    0.882467      0.858215
# recall      0.521127    0.986928  0.839286    0.754027      0.839286
# f1-score    0.672727    0.893491  0.839286    0.783109      0.823517
# support    71.000000  153.000000  0.839286  224.000000    224.000000

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[ 37,  34],
#        [  2, 151]], dtype=int64)

# %%
conf_matrix = confusion_matrix(y_true=y_test, y_pred=y_pred)
fig, ax = plt.subplots(figsize=(5, 5))
ax.matshow(conf_matrix, cmap=plt.cm.Blues)
for i in range(conf_matrix.shape[0]):
    for j in range(conf_matrix.shape[1]):
        ax.text(x=j, y=i,s=conf_matrix[i, j], va='center', ha='center', size='x-small')
plt.xlabel('Predictions', fontsize=10)
plt.ylabel('Actuals', fontsize=10)
plt.title('Confusion Matrix of DECISION TREE CLASSIFIER', fontsize=10)
plt.show()

# %% [markdown]
# ## Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rfc = RandomForestClassifier()

# %%
rfc.fit(x_train, y_train)
# Out:
# RandomForestClassifier()

# %%
rfc.score(x_train, y_train)
# Out:
# 1.0

# %%
rfc.score(x_test, y_test)
# Out:
# 0.8705357142857143

# %%
rfc = RandomForestClassifier(n_estimators=200, min_samples_split=20, max_depth=3 )

# %%
rfc.fit(x_train, y_train)
rfc.score(x_train, y_train)
# Out:
# 0.7961538461538461

# %%
rfc.score(x_test, y_test)
# Out:
# 0.84375

# %%
print("Accuracy is", rfc.score(x_test, y_test)*100)
# Out:
# Accuracy is 84.375

# %%
y_pred = rfc.predict(x_test)
pd.DataFrame(classification_report(y_test, y_pred, output_dict=True))
# Out:
#                    0           1  accuracy   macro avg  weighted avg
# precision   1.000000    0.813830   0.84375    0.906915      0.872839
# recall      0.507042    1.000000   0.84375    0.753521      0.843750
# f1-score    0.672897    0.897361   0.84375    0.785129      0.826214
# support    71.000000  153.000000   0.84375  224.000000    224.000000

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[ 36,  35],
#        [  0, 153]], dtype=int64)

# %%
conf_matrix = confusion_matrix(y_true=y_test, y_pred=y_pred)
fig, ax = plt.subplots(figsize=(5,5))
ax.matshow(conf_matrix, cmap=plt.cm.Greens)
for i in range(conf_matrix.shape[0]):
    for j in range(conf_matrix.shape[1]):
        ax.text(x=j, y=i,s=conf_matrix[i, j], va='center', ha='center', size='x-small')
plt.xlabel('Predictions', fontsize=10)
plt.ylabel('Actuals', fontsize=10)
plt.title('Confusion Matrix of RANDOM FOREST', fontsize=10)
plt.show()

# %%
import pickle
file=open("model.pkl", 'wb')
pickle.dump(model, file)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[308], line 3
#       1 import pickle
#       2 file=open("model.pkl", 'wb')
# ----> 3 pickle.dump(model, file)
#
# NameError: name 'model' is not defined
